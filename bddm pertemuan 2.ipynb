# %% [markdown]
# #LIST

# %%
list1 =['BigData & Data Mining', 'BigData & Predictive Analytic',2022,2022]
list2 =['buku','pensil','penggaris','spidol','bolpoin','penghapus']
list3 =['A','B','C','D']

# %%
print('list1[0]= ', list1[0])
print('list2[1:5]= ', list2[1:5])
# Out:
# list1[0]=  BigData & Data Mining
# list2[1:5]=  ['pensil', 'penggaris', 'spidol', 'bolpoin']

# %%
print('list3[2:4]', list3[2:4])
# Out:
# list3[2:4] ['C', 'D']

# %%
print(list2[1], ' ', list2[2])
print(list2[1:3])
# Out:
# pensil   penggaris
# ['pensil', 'penggaris']

# %%
import pandas as pd

data = {'buah': ['apel','pisang','jeruk','nanas','durian'],
        'sayur': ['bayam','sawi','wortel','kentang','kacang'],
        'hewan': ['kucing','kambing','sapi','kelinci','buaya']}

df = pd.DataFrame(data)
df
# Out:
#      buah    sayur    hewan
# 0    apel    bayam   kucing
# 1  pisang     sawi  kambing
# 2   jeruk   wortel     sapi
# 3   nanas  kentang  kelinci
# 4  durian   kacang    buaya

# %%
print(data['hewan'][2])
# Out:
# sapi

# %%
print(data['sayur'][3],' ',data['hewan'][4])
# Out:
# kentang   buaya

# %% [markdown]
# #tuple

# %%
tup1 =('BigData & Data Mining', 'BigData & Predictive Analytic',2022,2022)
tup2 =(1,2,3,4,5)
tup3 =('A','B','C','D')

# %%
type tup1
# Out:
# ('BigData & Data Mining', 'BigData & Predictive Analytic', 2022, 2022)

# %%
len(tup2)
# Out:
# 5

# %%
print('tup1[0]:', tup1[0])
print('tup2[1:5]:', tup2[1:5])
# Out:
# tup1[0]: BigData & Data Mining
# tup2[1:5]: (2, 3, 4, 5)

# %%
print(tup2,'&',tup3)
print(tup2+tup3)
# Out:
# (1, 2, 3, 4, 5) & ('A', 'B', 'C', 'D')
# (1, 2, 3, 4, 5, 'A', 'B', 'C', 'D')

# %%
print(type(tup1[0]))
print(type(tup2[1]))
print(type(tup3[2]))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'str'>

# %%
tup_nim=(3,2,0,1)
print(tup_nim)
# Out:
# (3, 2, 0, 1)

# %% [markdown]
# #DICTIONARY

# %%
dict={'Name': 'Zahra','Age':20,'Class':'BigData1'}

print("dict['name']:", dict['Name'])
print("dict['age']:", dict['Age'])

print(dict)
# Out:
# dict['name']: Zahra
# dict['age']: 20
# {'Name': 'Zahra', 'Age': 20, 'Class': 'BigData1'}

# %%
dict['Age']=8
dict['Univ']='Amikom'

print(dict)
# Out:
# {'Name': 'Zahra', 'Age': 8, 'Class': 'BigData1', 'Univ': 'Amikom'}

# %%
dict=[dict,{'Name': 'Tatang','Age':11,'Class':'BigData1'}]
print(dict)

dict=[{'Name': 'Zahra','Age':20,'Class':'BigData1'},{'Name': 'Tatang','Age':11,'Class':'BigData1'}]
print(dict)
# Out:
# [{'Name': 'Zahra', 'Age': 8, 'Class': 'BigData1', 'Univ': 'Amikom'}, {'Name': 'Tatang', 'Age': 11, 'Class': 'BigData1'}]
# [{'Name': 'Zahra', 'Age': 20, 'Class': 'BigData1'}, {'Name': 'Tatang', 'Age': 11, 'Class': 'BigData1'}]

# %%
data=[{'Name': 'Zara','Age':20,'Class':'BigData1'},
      {'Name': 'Lala','Age':21,'Class':'BigData2'},
      {'Name': 'Lili','Age':22,'Class':'BigData3'}]

df2 = pd.DataFrame(data)
df2
# Out:
#    Name  Age     Class
# 0  Zara   20  BigData1
# 1  Lala   21  BigData2
# 2  Lili   22  BigData3
